# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Purvesh\\Desktop\\01.Data Cleaning and Preprocessing.csv")
print(df)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.head() #shows first few rows
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.tail() #shows last few rows
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 319        347.286         310.970  1.523       513.956  ...        61.141
# 320        399.135         319.576  1.451       570.058  ...        67.667
# 321        373.633         314.591  1.457       549.306  ...        66.446
# 322        364.081         308.559  1.523       504.852  ...        61.054
# 323        356.289         310.482  1.474       497.375  ...        58.247
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.info() #shows summary of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
# printing column name
df.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
# to view summary statistics
df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
# visualizing data
df.plot

# %%
df.duplicated() #identifying duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 319     True
# 320     True
# 321     True
# 322     True
# 323     True
# Length: 324, dtype: bool

# %%
df.drop_duplicates() #removing duplicates
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.isnull().sum() # sum of all null values
#df.dropna()  # drop rows with missing values
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
data2=df.fillna(value=0) #filling with an integer value
data2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data2=df.fillna(method="pad") #forward filling
data2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data2=df.fillna(method="bfill") #backward filling
data2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#filtering rows
filter_df=df[df['ChipRate'] == 10.833]
filter_df
# Out:
#    Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 37     1-12:00    14.53    10.833      93.121  1202.818      339.119
#
#     T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 37        342.535         324.194  1.258       601.694  ...        63.969
#
#     Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 37         322.04         299.894      146.584        602.04       838.948
#
#     WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 37      48.632         41.508          251.63           30.65
#
# [1 rows x 23 columns]

# %%
#sorting
#df.sort_values(by='ChipRate')                                                                   #single column
df.sort_values(by=['ChipRate','BlowFlow'])                                                      #multiple columns
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 284    11-19:00    20.20     9.983     102.237  1027.485      369.632
# 289    12-00:00    22.50    10.625      89.193  1010.855      322.470
# 37      1-12:00    14.53    10.833      93.121  1202.818      339.119
# 288    11-23:00    22.10    10.933      97.752  1038.618      333.743
# 36      1-11:00    12.81    10.942     114.567  1241.142      215.485
# ..          ...      ...       ...         ...       ...          ...
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 206     8-13:00    16.70       NaN         NaN       NaN        0.000
# 314     8-13:00    16.70       NaN         NaN       NaN        0.000
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#grouping

#df.groupby('ChipRate').sum()                                                                     #single column
df.groupby(['ChipRate','BlowFlow']).count()                                                       #multiple columns
# Out:
#                    Observation  Y-Kappa  BF-CMratio  ChipLevel4   \
# ChipRate BlowFlow
# 9.983    1027.485            1        1           1            1
# 10.625   1010.855            1        1           1            1
# 10.833   1202.818            1        1           1            1
# 10.933   1038.618            1        1           1            1
# 10.942   1241.142            1        1           1            1
# ...                        ...      ...         ...          ...
# 16.817   1237.844            1        1           1            1
# 16.825   1246.387            1        1           1            1
# 16.833   1236.911            1        1           1            1
# 16.867   1284.849            1        1           1            1
# 16.958   1230.776            1        1           1            1
#
#                    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   \
# ChipRate BlowFlow
# 9.983    1027.485              1               1      1             1
# ...

# %%
import numpy as np
from scipy import stats

# %%
df.columns                                                                    #print outliers
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
df.drop(['Y-Kappa'],axis=1, inplace=True)
df.columns
# Out:
# Index(['Observation', 'ChipRate', 'BF-CMratio', 'BlowFlow', 'ChipLevel4 ',
#        'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA', 'WhiteFlow-4 ',
#        'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ', 'SteamFlow-4 ',
#        'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ', 'WeakLiquorF ',
#        'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ', 'T-Top-Chips-4 ',
#        'SulphidityL-4 '],
#       dtype='object')

# %%
#iqr formula
q1 = data2.quantile(0.25)
q3 = data2.quantile(0.75)
IQR = q3 - q1
print(IQR)
# Out:
# Observation              NaN
# Y-Kappa              4.65000
# ChipRate             2.21100
# BF-CMratio          10.74050
# BlowFlow            96.18700
# ChipLevel4         109.01075
# T-upperExt-2        12.09050
# T-lowerExt-2         7.75650
# UCZAA                0.12625
# WhiteFlow-4         98.45550
# AAWhiteSt-4          0.10800
# AA-Wood-4            1.45475
# ChipMoisture-4       2.22000
# SteamFlow-4          8.98050
# Lower-HeatT-3        8.44925
# Upper-HeatT-3        7.71450
# ChipMass-4          19.70375
# WeakLiquorF        174.05550
# BlackFlow-2        271.73125
# WeakWashF          271.19925
# SteamHeatF-3         6.93650
# T-Top-Chips-4        2.01025
# SulphidityL-4        0.83550
# dtype: float64

# %%
#formula for cleaning data
data2=data2[((data2<(q1-1.5*IQR))|(data2>(q3+1.5*IQR))).any(axis=1)]
data2
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0            NaN    23.10    16.520     121.717  1177.607      169.805
# 17           NaN    17.40    15.158      87.057  1218.797        6.476
# 35           NaN    12.17    12.667     114.570  1253.584      188.043
# 36           NaN    12.81    10.942     114.567  1241.142      215.485
# 38           NaN    18.45    12.917      84.483  1175.728      391.599
# ..           ...      ...       ...         ...       ...          ...
# 314          NaN    16.70    13.114      78.367  1276.082        0.000
# 315          NaN    16.05    13.114      78.367  1276.082        0.000
# 316          NaN    17.75    11.283      78.367  1276.082       41.607
# 320          NaN    19.80    12.558      94.352  1184.119      297.071
# 322          NaN    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data2.describe()  #shows clean data having no duplicates & null values
# Out:
#        Observation    Y-Kappa   ChipRate  BF-CMratio     BlowFlow  \
# count          0.0  67.000000  67.000000   67.000000    67.000000
# mean           NaN  20.300448  13.172612   91.170194  1105.677478
# std            NaN   3.178251   1.575164    9.501417   297.689455
# min            NaN  12.170000   9.983000   77.912000     0.000000
# 25%            NaN  18.055000  11.841500   85.487500  1059.759000
# 50%            NaN  20.550000  13.114000   90.515000  1189.517000
# 75%            NaN  22.650000  14.404000   93.963000  1274.056000
# max            NaN  27.100000  16.520000  121.717000  1312.077000
#
#        ChipLevel4   T-upperExt-2   T-lowerExt-2        UCZAA  WhiteFlow-4   \
# count    67.000000      67.000000       67.000000  67.000000     67.000000
# mean    242.085657     358.358418      320.195701   1.496552    550.802642
# std     132.176255      13.979638       11.707258   0.144582     73.799244
# ...
